# %% [markdown]
# # 🐍 PYTHON
#
#   # **Chapter 1: Getting Started with Python.**

# %% [markdown]
# INTRODUCTION
#
# WHY PYTHON.
#
# Python is known for its simplicity and readability, making it perfect for beginners. It is a high-level, interpreted language with a broad range of libraries and frameworks,supporting applications in web development, data analysis, AI and more.
#
# Python's versatility and ease of use make it a valuable tool for beginner and experienced programmers.

# %% [markdown]
# ## **FEATURES OF PYTHON.**

# %% [markdown]
# - Easy to Understand =  Less development time.
# - Free and Open Source.
# - High level Language.
# - Portable: Works on linux/Windows/Mac.
# - Fun to work with!

# %% [markdown]
# - MODULES, COMMENTS & PIP.

# %% [markdown]
# Let just create our first python code or program what every you to say.

# %%
print("hello world") # print is  a function (more later)
# Out:
# hello world

# %% [markdown]
# ## **Modules**
#
# A Module is a file containing code written by somebody else(**usually**) which can be imported and used in our programs.

# %% [markdown]
# *Dynamic types in python*
#
# Python as a script or language is what "Dynamically typed", meaning the variable are declared during runtime and there datatype is not explicity specfied.

# %%
a=30
a="shaurya"
a[1]
# Out:
# 'h'

# %% [markdown]
# **What is the command to check the data type?**
#
# Type() : Gives the data types of the variable currently in use.

# %% [markdown]
# ----
# ----

# %% [markdown]
# **WHAT ARE THE IMMUTABLE DATA TYPES() ?**
#
# *The data types where values cannot be changed once assigned.
#
# **Immutable Data Types**
#
# 1--> Integer (int)
#
# 2--> Floating Point (float)
#
# 3--> Boolean (bool)
#
# 4--> string (str)
#
# 5--> frozenset
#
# 6--> tuples

# %% [markdown]
# ----
# ----

# %% [markdown]
#  ## **Python is a Object-Oriented Language.**
#
# In python, **everything is an Object**.
#
# That means these are all Objects.
#
# - Integers -> 20
# - string -> "shaurya"
# - lists -> [1,2,3]
# - functions -> print, len
# - classes -> str, list
# - even module -> math, os

# %% [markdown]
# ----
# ----

# %% [markdown]
# So, in python:
#
# Data + Behavior are represented using objects.

# %% [markdown]
# # **WHAT IS AN OBJECT IN PYTHON ?**
#
# Definition (theoretical)
#
# - An object is a runtime entity that has:
# - Identity -> unique memory reference (id())
# - type -> what kind of object it is (type())
# - value / state -> actual data stored.

# %% [markdown]
# ----
# ----

# %% [markdown]
# # **Python`s Class-based Object System**
# # In Python, every object is created from the class (type).
#
# Example

# %%
name="shaurya"

# %% [markdown]
# Interally, python treats it as: "shaurya" is an object its class is str. That is why this works.

# %%
str
# Out:
# str

# %% [markdown]
# because str is a class object.

# %% [markdown]
# ----
# ----

# %% [markdown]
# # *How Objects are Called / Accessed in Python.*
# # Dot Operator (.) is attribute access
#
# When you write:

# %%
"hello".upper()
# Out:
# 'HELLO'

# %% [markdown]
# As the python intercepts:-
# - "hello" --> object
# - upper --> attribute (method) stored inside the class str.
#
# So internally it becomes:

# %%
str.upper("hello")
# Out:
# 'HELLO'

# %% [markdown]
# # Meaning:
#
# + Methods are just functions stored inside a class, and python passes the object automatically.
#
# ----

# %% [markdown]
# # Built-in function VS Methods
#
# # A. *Built-in Function (Global/ Independent)*
#
# when i write:

# %%
len("python")
# Out:
# 6

# %% [markdown]
# # Internal Meaning:
#
# Python searches len inside the **built-in namespaces**.
#
# Built-in live in:
#
# * __built-ins__
# * built-ins module
#
# so, this is basically:
#
# built-ins.len ("python")
#
# built-in functions are not tied to one object.

# %% [markdown]
# ----
# ----

# %% [markdown]
# # Method (belongs to an object's class).
#
# Example:

# %%
"python".upper()
# Out:
# 'PYTHON'

# %% [markdown]
# # *Internal Meaning*
#
# Python does:
#
# * look at object type -> *str*
# * find *upper* inside *str*
# * bind it with the object *"Python"*
# * then call it.
#
# Equivalent internal call.
#
# str.upper("python")
#
# So, **method = function that becomes bound to an object**.
#
# ----

# %% [markdown]
# # *Why Method fell different*?
#
# Because in methods:
#
# **Python automatically passes the object as the first argument**.
#
# That object is called:
#
# Example:

# %%
class Demo:
    def show(self):
        print("hello")

d=Demo()
d.show()
# Out:
# hello

# %% [markdown]
# So, d.show() is a shortcut for demo.show(d)
#
# ----
# ----

# %% [markdown]
# # *Why len() is a function but append() is a method?*
#
# Because of **design** of the code.
#
# len() **is general-purpose**.
#
# it works for many objects.
#
# + List
# + String
# + tuple
# + dict
# + set
#
# Python calls the object's internal length rule.
#
# **obj.__len__()**
#
# So,
#    **len(obj)**
#
#    internally becomes:
#
#    **obj.__len__()**
#
#    len() is a built-in function that **calls the method indirectly**.

# %% [markdown]
# ----
# ----

# %% [markdown]
# # *Variable-Native Language or python*
# A variable in any programming language is a named storage location in memory that holds data, and the value can change while the program runs.
#
# **Naming and Using Variables**:
#
# *Main Points*
#
# **The python variables you're using at this point should be lowercase. You won't get errors if you use uppercase letter, but it's a good idea to avoid using them for now.**
#
# ----
#
# *Variable types*
#
# *string : A string is a series of characters in a sequence, they are written within "" or ''.*

# %%
message="hello Python Crash course Reader!"
print(message)
# Out:
# hello Python Crash course Reader!

# %% [markdown]
# # *Python string built-in Methods (full list)*.
#
# *1. Case Conversion Methods*
#
#  * lower()
#
# definition and Usage
#
# Return a copy of the string with all the cased characters converted to lowercase. For example:
#
# ----

# %%
A="Python"
A.lower()
# Out:
# 'python'

# %% [markdown]
# ----
# ----

# %% [markdown]
# * upper()
#
# *Definition and Usage*
#
# Return a copy of the string with all the cased characters converted to uppercase. Note that *s.upper()* , *isupper()* might be false. If s contains uncased character(s) is not "lu" *(letter, uppercase)* , but e.g. "Lt" *(letter, titlecase)*.

# %%
"python".upper()
# Out:
# 'PYTHON'

# %% [markdown]
# ----
# ----

# %% [markdown]
# * Title()
#
# *Definition and Usage*
#
# Return a title cased version of the string where words start with an uppercase character and the remaining characters are lowercase.

# %%
"Python programming".title()
# Out:
# 'Python Programming'

# %% [markdown]
# ----
# ----

# %% [markdown]
# * capitalize()
#
# *Definition and Usage*
#
# The capitalize() Return a copy of the string with its first character capitalized and the rest lowercased.

# %%
"Python programming".capitalize()
# Out:
# 'Python programming'

# %% [markdown]
# ----
# ----

# %% [markdown]
# * swapcase()
#
# *Definition and Usage*
#
# The swapcase() method returns a string where all the uppercase letters are lowercase and vice-versa.

# %%
"PyTHon".swapcase()
# Out:
# 'pYthON'

# %% [markdown]
# ----
# ----

# %% [markdown]
# * casefold()
#
# *definition and Usage*
#
# Return a casefolded copy of the string. Casefolded strings may be used for caseless matching.
#
# Casefolding is similar to lowercasing but more aggressive because it is intended to remove all case distinctions in a string. For example, the german lowercase letter '🪢' is equivalent to "ss". Since it is already lowercase, lower() would do nothing to '🪢'; casefold() convert it to "ss".
#
# For Example:

# %%
"GERMAN".casefold()
# Out:
# 'german'

# %% [markdown]
# ----
# ----
